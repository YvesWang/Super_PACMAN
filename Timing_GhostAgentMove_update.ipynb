# %%
for i in range(50):
    print(i)
    # !time python3 ../python_version/pacman.py --ghosts ShortestPathGhost
# Out:
# 0
# Pacman died! Score: -515
# self.totalAgentTimes[0]: 65.03982977433638
# self.totalAgentTimes[1]: 14.770681207830256
# self.totalAgentTimes[2]: 12.630440972068094
# *************************************
# total_step: 44, total_time: 3.8285298347473145, average_time is 0.0870120416988026
#
# real	0m5.510s
# user	0m1.127s
# sys	0m0.273s
# 1
# Pacman died! Score: -517
# self.totalAgentTimes[0]: 62.75568008422851
# self.totalAgentTimes[1]: 14.911365509033201
# self.totalAgentTimes[2]: 12.047195434570312
# *************************************
# total_step: 50, total_time: 4.081501007080078, average_time is 0.08163002014160156
#
# real	0m5.768s
# user	0m1.257s
# sys	0m0.282s
# 2
# Pacman died! Score: -515
# self.totalAgentTimes[0]: 80.71400902488016
# self.totalAgentTimes[1]: 13.689507137645375
# self.totalAgentTimes[2]: 12.061324986544523
# *************************************
# total_step: 44, total_time: 4.300325155258179, average_time is 0.09773466261950406
#
# real	0m5.971s
# ...

# %%
160/29
# Out:
# 5.517241379310345

# %%
for i in range(50):
    print(i)
    # !time python3 ../cythonized_versionpytho/pacman.py --ghosts ShortestPathGhost
# Out:
# 0
# Pacman died! Score: -530
# self.totalAgentTimes[0]: 47.85529772440592
# self.totalAgentTimes[1]: 13.706286748250326
# self.totalAgentTimes[2]: 9.570121765136719
# *************************************
# total_step: 90, total_time: 7.357295036315918, average_time is 0.08174772262573242
#
# real	0m9.063s
# user	0m1.702s
# sys	0m0.400s
# 1
# Pacman died! Score: -517
# self.totalAgentTimes[0]: 98.4748363494873
# self.totalAgentTimes[1]: 14.660167694091795
# self.totalAgentTimes[2]: 11.97967529296875
# *************************************
# total_step: 50, total_time: 5.499198913574219, average_time is 0.10998397827148437
#
# real	0m7.088s
# user	0m1.283s
# sys	0m0.291s
# 2
# Pacman died! Score: -517
# self.totalAgentTimes[0]: 152.10728645324707
# self.totalAgentTimes[1]: 14.226293563842772
# self.totalAgentTimes[2]: 12.63613700866699
# *************************************
# total_step: 50, total_time: 6.914736032485962, average_time is 0.13829472064971923
#
# real	0m8.504s
# ...

# %% [markdown]
# ### Average time for a ghost agent to make a move in python version (20 games)

# %%
(14.770681207830256 + 12.630440972068094 + 14.911365509033201 + 12.047195434570312 + 13.689507137645375 + 12.061324986544523 + 14.473524960604582 + 14.21001824465665 + 13.86945897882635 + 12.10960474881259 + 17.217546701431274 + 11.111050844192505 + 14.743696559559217 + 14.35940915888006 + 15.480897643349389 + 11.787577108903365 + 14.7932767868042 + 12.134801257740367 + 14.754750511863016 + 12.830062346024947 + 15.371821143410422 + 10.994997891512783 + 16.613304615020752 + 11.303573846817017 + 15.748898188273111 + 11.560440063476562 + 14.80709422718395 + 18.178874796087094 + 17.08000898361206 + 10.868608951568604 + 14.737519350918857 + 13.731284575028853 + 14.381679621609775 + 12.436671690507369 + 15.249414877458053 + 18.473267555236816 + 16.032010316848755 + 12.40462064743042 + 14.634457501498137 + 14.39322124827992)
# Out:
# 562.9879611911194

# %%
562.9879611911194/40
# Out:
# 14.074699029777985

# %% [markdown]
# ### Average time for a ghost agent to make a move in cythonized version (20 games)

# %%
500.89003544321434/40
# Out:
# 12.522250886080359

# %%
(13.706286748250326 + 9.570121765136719 + 14.660167694091795 + 11.97967529296875 + 14.226293563842772 + 12.63613700866699 + 14.171925458041104 + 9.244788776744496 + 13.249715169270834 + 10.932551489935982 + 12.269561940973455 + 12.4712965705178 + 12.912641872059215 + 14.4416635686701 + 13.078451156616211 + 10.734037919477984 + 13.642365282232111 + 10.293830524791371 + 16.289461742747914 + 10.843276977539062 + 12.429681691256437 + 14.870817011052912 + 12.960664687618133 + 12.705133807274603 + 13.021068139509723 + 11.203018101778898 + 14.25662040710449 + 12.135171890258789 + 14.056075703014027 + 11.40914180062034 + 12.496493079445578 + 11.514642021872781 + 12.421553785150701 + 11.122714389454234 + 13.100396503101695 + 11.463273655284535 + 13.979226350784302 + 10.652542114257812 + 12.762447198232016 + 10.9751025835673)
# Out:
# 500.89003544321434

# %% [markdown]
# ### Relative speed improvement

# %%
(14.074699029777985-12.522250886080359)/14.074699029777985
# Out:
# 0.11030062812803995

# %%
# !pwd
# Out:
# /Users/zhe/advanced_python/pec_man/Super_PACMAN
