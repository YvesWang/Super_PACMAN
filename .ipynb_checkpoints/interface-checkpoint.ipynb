# %%
from tkinter import *
from tkinter import filedialog #.askopenfilename
from PIL import ImageTk, Image
import os
import random

def PacmanGame():
    # !python pacman.py
def PacmanGame5():
    # !python pacman.py --numGames 5
def PacmanGame10():
    # !python pacman.py --numGames 10
def PacmanGame20():
    # !python pacman.py --numGames 20
def simpleGame():
    # !python pacman.py -l smallClassic -z 2
def DirectionalGhost():
    # !python pacman.py -g DirectionalGhost --numGames 5
def ShortestPathGhost():
    # !python pacman.py -g ShortestPathGhost --numGames 5
def maxGhosts():
    # !python pacman.py -k 1
def About():
    test = Tk()
    test.title("Credits")
    w = Label(test, text="This modified version of Pacman has been developed by group 10")
    w.pack()
    print("This is a simple example of a menu")

root = Tk()
root.title("Please use menu to start")
root.geometry("405x405")

img = ImageTk.PhotoImage(Image.open("pacman.gif"))
panel = Label(root, image = img)
panel.pack(side = "bottom", fill = "both", expand = "yes")

menu = Menu(root)
root.config(menu=menu)
filemenu = Menu(menu)
menu.add_cascade(label="File", menu=filemenu)
filemenu.add_command(label="New Pacman Game (1 Game)", command=PacmanGame)
filemenu.add_command(label="New Pacman Game (5 Games)", command=PacmanGame5)
filemenu.add_command(label="New Pacman Game (10 Games)", command=PacmanGame10)
filemenu.add_command(label="New Pacman Game (20 Games)", command=PacmanGame20)
filemenu.add_command(label="Simple Pacman", command=simpleGame)
filemenu.add_command(label="Max Ghosts 1", command=maxGhosts)
filemenu.add_command(label="Directional Ghost", command=DirectionalGhost)
filemenu.add_command(label="Shortest Path Ghost", command=ShortestPathGhost)
filemenu.add_separator()
filemenu.add_command(label="Exit", command=root.destroy)


helpmenu = Menu(menu)
menu.add_cascade(label="Help", menu=helpmenu)
helpmenu.add_command(label="About...", command=About)

root.mainloop()
# Out:
# 14
# 15
# 13
# 15
# 14
# 14
# 12
# 14
# 13
# 15
# 13
# 11
# 12
# 14
# 10
# 13
# 11
# 8
# 9
# 8
# 6
# 8
# 7
# 4
# 7
# 5
# 7
# 3
# 5
# 4
# 2
# 3
# 5
# 0
# 2
# 2
# Pacman died! Score: -471
